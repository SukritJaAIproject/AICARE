# %%
import AUmaps
import glob
import dlib
import matplotlib.pyplot as plt
AUdetector = AUmaps.AUdetector('shape_predictor_68_face_landmarks.dat',enable_cuda=False)
path_imgs = 'example_video'
files = sorted(glob.glob(path_imgs + '/*.png'))
fig = plt.figure(figsize=plt.figaspect(.5))
for names in files:
    print(names)
    img = dlib.load_rgb_image(names)
    pred,map,img = AUdetector.detectAU(img)
    for j in range(0,5):
        resized_map = dlib.resize_image(map[j,:,:].cpu().data.numpy(),rows=256,cols=256)
        ax = fig.add_subplot(5,2,2*j+1)
        ax.imshow(img)
        ax.axis('off')
        ax = fig.add_subplot(5, 2, 2*j+2)
        ax.imshow(resized_map)
        ax.axis('off')
    plt.pause(.1)
    plt.draw()
# Out:
# 0
# example_video\frame_0001.png
# C:\Users\sukri\anaconda3\envs\tf-gpu\lib\site-packages\torch\nn\functional.py:2952: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# example_video\frame_0002.png
# C:\Users\sukri\anaconda3\envs\tf-gpu\lib\site-packages\ipykernel_launcher.py:15: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   from ipykernel import kernelapp as app
# C:\Users\sukri\anaconda3\envs\tf-gpu\lib\site-packages\ipykernel_launcher.py:18: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# example_video\frame_0003.png
# example_video\frame_0004.png
# example_video\frame_0005.png
# example_video\frame_0006.png
# example_video\frame_0007.png
# example_video\frame_0008.png
# example_video\frame_0009.png
# example_video\frame_0010.png
# example_video\frame_0011.png
# example_video\frame_0012.png
# example_video\frame_0013.png
# example_video\frame_0014.png
# example_video\frame_0015.png
# example_video\frame_0016.png
# example_video\frame_0017.png
# example_video\frame_0018.png
# example_video\frame_0019.png
# example_video\frame_0020.png
# example_video\frame_0021.png
# example_video\frame_0022.png
# example_video\frame_0023.png
# example_video\frame_0024.png
# example_video\frame_0025.png
# example_video\frame_0026.png
# example_video\frame_0027.png
# example_video\frame_0028.png
# example_video\frame_0029.png
# example_video\frame_0030.png
# example_video\frame_0031.png
# example_video\frame_0032.png
# example_video\frame_0033.png
# example_video\frame_0034.png
# example_video\frame_0035.png
# example_video\frame_0036.png
# example_video\frame_0037.png
# example_video\frame_0038.png
# example_video\frame_0039.png
# example_video\frame_0040.png
# example_video\frame_0041.png
# example_video\frame_0042.png
# example_video\frame_0043.png
# example_video\frame_0044.png
# example_video\frame_0045.png
# example_video\frame_0046.png
# example_video\frame_0047.png
# example_video\frame_0048.png
# example_video\frame_0049.png

# %%
import cv2, time, dlib, matplotlib.pyplot as plt, numpy as np
import AUmaps

AUdetector = AUmaps.AUdetector('shape_predictor_68_face_landmarks.dat',enable_cuda=True)
cam = cv2.VideoCapture(0)

fig = plt.figure(figsize=plt.figaspect(.5))
axs = fig.subplots(5, 2)

# Init subplots and images within
implots = []
for ax in axs.reshape(-1):
    ax.axis('off')
    implots.append(ax.imshow(np.zeros((256, 256))))

tstart_time = time.time()
nframes = 0
while True:
    start_time = time.time()
    _, img = cam.read()

    # Downscale webcam image 2x to speed things up
    img = cv2.resize(img, None, fx = 0.5, fy = 0.5)

    # Optionally flip webcam image, probably not relevant
    # img = cv2.flip(img, 1)

    # Optionally display webcam image with opencv
    # cv2.imshow('Action Unit Heatmaps - Press Q to exit!', img)
    # if cv2.waitKey(1) & 0xFF == ord('q'):
    # 	break

    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    nframes += 1

    pred,map,img = AUdetector.detectAU(img)
    for j in range(0,5):
        resized_map = dlib.resize_image(map[j,:,:].cpu().data.numpy(),rows=256,cols=256)

        # Update face image subplot
        implots[2*j].set_data(img)

        # Update heatmap subplot
        implots[2*j+1].set_data(resized_map)

        # Set correct heatmap limits
        resized_map_flat = resized_map.flatten()
        implots[2*j+1].set_clim(min(resized_map_flat), max(resized_map_flat))

        # To plot heatmaps the original way - looks identical to the new way!
        # ax = fig.add_subplot(5,2,2*j+1)
        # ax.imshow(resized_map)
        # ax.axis('off')

    plt.pause(0.001)
    plt.draw()

    elapsed_time = time.time() - start_time
    print(' ** FPS Elapsed: {0:.3f}'.format(1.0 / elapsed_time))

# Close camera
cam.release()

# If webcam images shown with opencv, close window
# cv2.destroyAllWindows()

telapsed_time = time.time() - tstart_time
print('\n ** Mean FPS Elapsed: {0:.3f} \n'.format(1.0 / (telapsed_time / nframes)))
# Out:
# 0
#  ** FPS Elapsed: 0.316
#  ** FPS Elapsed: 3.984
#  ** FPS Elapsed: 5.747
#  ** FPS Elapsed: 5.682
#  ** FPS Elapsed: 5.917
#  ** FPS Elapsed: 5.988
#  ** FPS Elapsed: 5.917
#  ** FPS Elapsed: 5.952
#  ** FPS Elapsed: 5.988
#  ** FPS Elapsed: 6.135
#  ** FPS Elapsed: 6.097
#  ** FPS Elapsed: 5.952
#  ** FPS Elapsed: 5.435
#  ** FPS Elapsed: 5.814
#  ** FPS Elapsed: 6.536
#  ** FPS Elapsed: 6.410
#  ** FPS Elapsed: 6.410
#  ** FPS Elapsed: 6.250
#  ** FPS Elapsed: 5.988
#  ** FPS Elapsed: 6.757
#  ** FPS Elapsed: 6.536
#  ** FPS Elapsed: 6.024
#  ** FPS Elapsed: 5.917
#  ** FPS Elapsed: 5.814
#  ** FPS Elapsed: 6.024
#  ** FPS Elapsed: 5.780
#  ** FPS Elapsed: 6.173
#  ** FPS Elapsed: 6.061
#  ** FPS Elapsed: 7.634
#  ** FPS Elapsed: 6.897
#  ** FPS Elapsed: 6.493
#  ** FPS Elapsed: 8.547
#  ** FPS Elapsed: 7.692
#  ** FPS Elapsed: 7.353
#  ** FPS Elapsed: 6.536
#  ** FPS Elapsed: 6.024
#  ** FPS Elapsed: 6.135
#  ** FPS Elapsed: 5.682
#  ** FPS Elapsed: 5.780
#  ** FPS Elapsed: 5.714
#  ** FPS Elapsed: 5.848
#  ** FPS Elapsed: 5.618
#  ** FPS Elapsed: 5.882
#  ** FPS Elapsed: 5.988
#  ** FPS Elapsed: 5.988
#  ** FPS Elapsed: 6.061
#  ** FPS Elapsed: 5.814
#  ** FPS Elapsed: 6.024
#  ** FPS Elapsed: 6.173
#  ** FPS Elapsed: 5.848
#  ** FPS Elapsed: 5.848
#  ** FPS Elapsed: 5.814
#  ** FPS Elapsed: 5.882
#  ** FPS Elapsed: 3.356
#  ** FPS Elapsed: 3.521
#  ** FPS Elapsed: 3.448
#  ** FPS Elapsed: 3.311
#  ** FPS Elapsed: 3.345
#  ** FPS Elapsed: 3.436
#  ** FPS Elapsed: 3.378
#  ** FPS Elapsed: 3.247
#  ** FPS Elapsed: 2.793
#  ** FPS Elapsed: 2.865
#  ** FPS Elapsed: 3.322
#  ** FPS Elapsed: 3.413
#  ** FPS Elapsed: 3.300
#  ** FPS Elapsed: 3.300
#  ** FPS Elapsed: 3.484
#  ** FPS Elapsed: 3.195
#  ** FPS Elapsed: 3.236
#  ** FPS Elapsed: 3.106
#  ** FPS Elapsed: 3.039
#  ** FPS Elapsed: 3.040
#  ** FPS Elapsed: 3.257
#  ** FPS Elapsed: 3.039
#  ** FPS Elapsed: 3.058
#  ** FPS Elapsed: 3.509
#  ** FPS Elapsed: 3.185
#  ** FPS Elapsed: 3.106
#  ** FPS Elapsed: 3.205
#  ** FPS Elapsed: 3.215
#  ** FPS Elapsed: 3.077
#  ** FPS Elapsed: 3.413
#  ** FPS Elapsed: 3.279
#  ** FPS Elapsed: 3.040
#  ** FPS Elapsed: 3.356
#  ** FPS Elapsed: 3.356
#  ** FPS Elapsed: 3.584
#  ** FPS Elapsed: 3.623
#  ** FPS Elapsed: 2.849
#  ** FPS Elapsed: 3.077
#  ** FPS Elapsed: 3.610
#  ** FPS Elapsed: 3.300
#  ** FPS Elapsed: 3.344
#  ** FPS Elapsed: 3.247
#  ** FPS Elapsed: 3.185
#  ** FPS Elapsed: 3.175
#  ** FPS Elapsed: 2.967
#  ** FPS Elapsed: 3.096
#  ** FPS Elapsed: 3.390
#  ** FPS Elapsed: 3.497
#  ** FPS Elapsed: 3.378
#  ** FPS Elapsed: 3.460
#  ** FPS Elapsed: 3.311
#  ** FPS Elapsed: 3.175
#  ** FPS Elapsed: 3.344
#  ** FPS Elapsed: 3.289
#  ** FPS Elapsed: 3.497
#  ** FPS Elapsed: 3.257
#  ** FPS Elapsed: 3.279
#  ** FPS Elapsed: 3.106
#  ** FPS Elapsed: 3.125
#  ** FPS Elapsed: 3.279
#  ** FPS Elapsed: 3.247
#  ** FPS Elapsed: 2.959
#  ** FPS Elapsed: 3.356
#  ** FPS Elapsed: 3.289
#  ** FPS Elapsed: 3.257
#  ** FPS Elapsed: 3.367
#  ** FPS Elapsed: 3.497
#  ** FPS Elapsed: 3.344
#  ** FPS Elapsed: 3.460
#  ** FPS Elapsed: 3.215
#  ** FPS Elapsed: 3.135
#  ** FPS Elapsed: 3.413
#  ** FPS Elapsed: 3.333
#  ** FPS Elapsed: 3.356
#  ** FPS Elapsed: 3.311
#  ** FPS Elapsed: 3.367
#  ** FPS Elapsed: 3.257
#  ** FPS Elapsed: 3.378
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-05750f5a7a5b> in <module>
#      45
#      46                 # Set correct heatmap limits
# ---> 47                 resized_map_flat = resized_map.flatten()
#      48                 implots[2*j+1].set_clim(min(resized_map_flat), max(resized_map_flat))
#      49
#
# KeyboardInterrupt:
