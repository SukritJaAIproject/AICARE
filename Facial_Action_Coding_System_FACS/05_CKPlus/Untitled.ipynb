# %%
# !python train.py C:\Users\sukri\Desktop\CK_dataset\CK+\emotion_images\  43 .1 .3 32 10
# Out:
# Recovering arrays for label 0
# Recovering arrays for label 1
# Recovering arrays for label 2
# Recovering arrays for label 3
# Recovering arrays for label 4
# Recovering arrays for label 5
# Recovering arrays for label 6
# Recovering arrays for label 7
#
# Shape of X array: (359, 3, 112, 112, 3)
# Shape of y array: (359, 8)
# Class distribution: {0: 43, 1: 45, 2: 16, 3: 56, 4: 24, 5: 69, 6: 28, 7: 78}
#
#   Training set =  (215, 3, 112, 112, 3)
# Validation set =  (36, 3, 112, 112, 3)
#       Test set =  (108, 3, 112, 112, 3)
#
# Train on 215 samples, validate on 36 samples
# Epoch 1/10
# 2021-03-29 15:16:43.747552: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cudart64_101.dll
# 2021-03-29 15:17:06.190848: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library nvcuda.dll
# ...

# %%
# !python train.py C:\Users\sukri\Desktop\CK_dataset\CK+\emotion_images\  43 .1 .3 8 10
# Out:
# Recovering arrays for label 0
# Recovering arrays for label 1
# Recovering arrays for label 2
# Recovering arrays for label 3
# Recovering arrays for label 4
# Recovering arrays for label 5
# Recovering arrays for label 6
# Recovering arrays for label 7
#
# Shape of X array: (359, 3, 112, 112, 3)
# Shape of y array: (359, 8)
# Class distribution: {0: 43, 1: 45, 2: 16, 3: 56, 4: 24, 5: 69, 6: 28, 7: 78}
# 2021-03-29 15:21:56.622058: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cudart64_101.dll
# 2021-03-29 15:22:22.289509: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library nvcuda.dll
# 2021-03-29 15:22:23.257295: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1555] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: Quadro P2000 computeCapability: 6.1
# coreClock: 1.607GHz coreCount: 6 deviceMemorySize: 4.00GiB deviceMemoryBandwidth: 89.53GiB/s
# ...
